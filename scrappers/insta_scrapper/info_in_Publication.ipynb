# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import bs4, time, pprint

#directory to find chrome webdriver
chrome_driver = r'C:\Users\Yan\Desktop\git\projects\scrappers\insta_scrapper\chromedriver_win32\chromedriver.exe'

#instance a chrome headless
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--window-size-1920x1080')

driver = webdriver.Chrome(options=chrome_options, executable_path=chrome_driver)

# %%
linkPub = 'https://www.instagram.com/p/By2hKC9gNVr/'

# %%
driver.get(linkPub)

# %%
htmlPage = bs4.BeautifulSoup(driver.page_source, features='html.parser')

# %%
publication = {}
profileName = htmlPage.find('h2',{'class':'BrX75'}).find('a').get('href')
publication.setdefault(profileName,{})
publication[profileName].setdefault('subtitle',{})
for linkInLegend in htmlPage.find('ul',{'class':'XQXOT'}).find('li').find_all('a'):
    publication[profileName]['subtitle'].setdefault('text',htmlPage.find('ul',{'class':'XQXOT'}).find('li').text)
    if linkInLegend.get('href') != profileName and linkInLegend.get('href').startswith('/explore/tags/'):
        publication[profileName]['subtitle'].setdefault('tags',[])
        publication[profileName]['subtitle']['tags'].append(linkInLegend.get('href'))
    elif linkInLegend.get('href') != profileName and not (linkInLegend.get('href').startswith('/explore/tags/')):
        publication[profileName]['subtitle'].setdefault('profile',[])
        publication[profileName]['subtitle']['profile'].append(linkInLegend.get('href'))
        
publication[profileName].setdefault('comments',{})
publication[profileName].setdefault('likes',htmlPage.find('a',{'class':'zV_Nj'}).text)
publication[profileName].setdefault('date',htmlPage.find('time').get('datetime'))
if htmlPage.find('div',{'class':'JF9hh'}).find('a') != None:
    publication[profileName].setdefault('location',htmlPage.find('div',{'class':'JF9hh'}).find('a').get('href'))

# %%
for listComment in htmlPage.find_all('ul',{'class':'Mr508'}):
    publication[profileName]['comments'].setdefault(str(listComment.find('a').get('href')),{})
    if len(listComment.find_all('a')) < 3 and listComment.find_all('a')[0].get('href') == listComment.find_all('a')[1].get('href'):
        publication[profileName]['comments'][str(listComment.find('a').get('href'))].setdefault('text',listComment.find('span').text)
        publication[profileName]['comments'][str(listComment.find('a').get('href'))].setdefault('date-comment',listComment.find('time').get('datetime'))
    else:
        for link in listComment.find_all('a'):
            publication[profileName]['comments'][str(listComment.find('a').get('href'))].setdefault('date-comment',listComment.find('time').get('datetime'))
            publication[profileName]['comments'][str(listComment.find('a').get('href'))].setdefault('text',listComment.find('span').text)
            if link.get('href').startswith('/explore/tags/'):
                publication[profileName]['comments'][str(listComment.find('a').get('href'))].setdefault('tags',[])
                publication[profileName]['comments'][str(listComment.find('a').get('href'))]['tags'].append(link.get('href'))
            elif link.get('href') != str(listComment.find('a').get('href')):
                publication[profileName]['comments'][str(listComment.find('a').get('href'))].setdefault('profiles',[])
                publication[profileName]['comments'][str(listComment.find('a').get('href'))]['profiles'].append(link.get('href'))

# %%
pprint.pprint(publication)
# Out:
# {'/ardenmedia/': {'comments': {'/austinbagnall/': {'date-comment': '2019-06-18T15:45:04.000Z',
#                                                    'text': 'I thought he was '
#                                                            'talking about '
#                                                            'cancelling his '
#                                                            'reading plans for '
#                                                            'a sec'},
#                                '/dawonj/': {'date-comment': '2019-06-18T14:09:33.000Z',
#                                             'text': '💓'},
#                                '/digivest.id/': {'date-comment': '2019-06-18T14:00:01.000Z',
#                                                  'text': '👍👍👍'},
#                                '/failure2famous/': {'date-comment': '2019-06-18T14:22:33.000Z',
#                                                     'text': 'Really respected'},
#                                '/iamevoriwall/': {'date-comment': '2019-06-18T13:52:20.000Z',
#                                                   'profiles': ['/valeriewall0714/'],
#                                                   'text': '@valeriewall0714'},
#                                '/lbarz_1385/': {'date-comment': '2019-06-18T14:35:20.000Z',
#                                                 'profiles': ['/parmsz/'],
#                                                 'text': '@parmsz'},
#                                '/lisa.baker05/': {'date-comment': '2019-06-18T16:19:39.000Z',
#                                                   'profiles': ['/franklouis0018/'],
#                                                   'text': 'I’ve been trading '
#                                                           'Forex and bitcoin '
#                                                           'for the last few '
#                                                           'years but since I '
#                                                           'started trading '
#                                                           'with Mr Frank my '
#                                                           'result changed and '
#                                                           'also my mindsets '
#                                                           'towards what am '
#                                                           'doing. I’m very '
#                                                           'happy with my '
#                                                           'progress and I’m '
#                                                           'getting paid '
#                                                           'weekly. I started '
#                                                           'with $1,000 and got '
#                                                           'back $25,000 in '
#                                                           '72hours.. I’m '
#                                                           'grateful as I never '
#                                                           'depends on a single '
#                                                           'income. I wish I '
#                                                           'had did this 3years '
#                                                           'ago with mr Frank.. '
#                                                           'I recommend him and '
#                                                           'you can DM him '
#                                                           '@franklouis0018'},
#                                '/monika_eldora/': {'date-comment': '2019-06-18T14:09:44.000Z',
#                                                    'profiles': ['/norvellwillams/'],
#                                                    'text': 'Have you been '
#                                                            'looking for a good '
#                                                            'site to earn money '
#                                                            'from?  I have a '
#                                                            'legit one with me, '
#                                                            'I made 1btc under '
#                                                            '42hours after the '
#                                                            'mining section. '
#                                                            'With $500 you earn '
#                                                            'amazing profit '
#                                                            'weekly of $4,500.. '
#                                                            'For more info via. '
#                                                            '@norvellwillams '
#                                                            'for more '
#                                                            'info.WhatsApp+15733133547'},
#                                '/monkmentor/': {'date-comment': '2019-06-18T13:45:38.000Z',
#                                                 'text': 'Amazing content😍 '
#                                                         'thanks for sharing😊 I '
#                                                         'love your content, it '
#                                                         'helps people out '
#                                                         'there.'},
#                                '/monks_moral/': {'date-comment': '2019-06-18T15:45:16.000Z',
#                                                  'text': 'Great one'},
#                                '/quentmilli/': {'date-comment': '2019-06-18T14:53:33.000Z',
#                                                 'profiles': ['/pecanbeauty/'],
#                                                 'text': '@pecanbeauty'},
#                                '/richardvankampen1964/': {'date-comment': '2019-06-18T16:42:30.000Z',
#                                                           'text': 'Great '
#                                                                   'post💯💯🔥🔥🔥👍'}},
#                   'date': '2019-06-18T12:54:40.000Z',
#                   'likes': '1,299 likes',
#                   'location': '/explore/locations/212988663/new-york-new-york/',
#                   'subtitle': {'profile': ['/businessadvicedaily/'],
#                                'tags': ['/explore/tags/personalgrowth/',
#                                         '/explore/tags/business/',
#                                         '/explore/tags/personaldevelopment/',
#                                         '/explore/tags/entrepreneur/',
#                                         '/explore/tags/youngentrepreneurs/',
#                                         '/explore/tags/success/',
#                                         '/explore/tags/selfgrowth/',
#                                         '/explore/tags/mindsetiseverything/',
#                                         '/explore/tags/solopreneur/',
#                                         '/explore/tags/youngentrepreneur/',
#                                         '/explore/tags/networker/',
#                                         '/explore/tags/marketing/',
#                                         '/explore/tags/entrepreneurship/',
#                                         '/explore/tags/wordsoftheday/',
#                                         '/explore/tags/startup/',
#                                         '/explore/tags/selfawareness/',
#                                         '/explore/tags/money/',
#                                         '/explore/tags/hardworker/',
#                                         '/explore/tags/booksforsaleph/',
#                                         '/explore/tags/prelovedbooksph/',
#                                         '/explore/tags/secondhandbooksph/',
#                                         '/explore/tags/booksaleph/',
#                                         '/explore/tags/successcoach/',
#                                         '/explore/tags/cheapbooksph/',
#                                         '/explore/tags/ebooksph/',
#                                         '/explore/tags/lookingforbooksph/',
#                                         '/explore/tags/entrepreneurial/',
#                                         '/explore/tags/onlyinthephilippines/',
#                                         '/explore/tags/businessman/',
#                                         '/explore/tags/inspireothers/'],
#                                'text': 'ardenmedia❤️ if you thinks it’s ok to '
#                                        'work on yourself.——⠀✅ Follow | '
#                                        '@ardenmedia\xa0| for more!\xa0💰✅ '
#                                        'Follow | @ardenmedia\xa0| for more! 💰✅ '
#                                        'Follow | @ardenmedia\xa0| for more!\xa0'
#                                        '💰—⠀ —⠀......Credit '
#                                        '@businessadvicedaily '
#                                        '......•••••#personalgrowth #business '
#                                        '#personaldevelopment #entrepreneur '
#                                        '#youngentrepreneurs #success '
#                                        '#selfgrowth #mindsetiseverything '
#                                        '#solopreneur #youngentrepreneur '
#                                        '#networker #marketing '
#                                        '#entrepreneurship #wordsoftheday '
#                                        '#startup #selfawareness #money '
#                                        '#hardworker #booksforsaleph '
#                                        '#prelovedbooksph #secondhandbooksph '
#                                        '#booksaleph #successcoach '
#                                        '#cheapbooksph #ebooksph '
#                                        '#lookingforbooksph #entrepreneurial '
#                                        '#onlyinthephilippines #businessman '
#                                        '#inspireothers5h'}}}
